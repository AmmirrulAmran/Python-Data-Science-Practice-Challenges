# %% [markdown]
# You decide to invest in a series of billboards along interstate 10 to advertise your stylish new chicken restaurant, Chic-fil-A 🐔.
#
#     You buy three billboards evenly spaced starting from mile marker 17 and ending on mile marker 28.
#     You buy another three billboards starting on mile marker 32 and ending on mile marker 36.
#     In order, from mile marker 17 to 36, your billboards display these ads: A, B, C, C, B, A.
#
# Determine how far each B ad is from your restaurant which is located at mile marker 30.
#
# # ads / restaurant*:   A     B     C   *   C  B  A
# # billboards:        --|-----|-----|---|---|--|--|--
# # mile markers:       17          28  30  32    36

# %%
import numpy as np

#location of Restaurant

Restaurant  = 30
#Location of C & A
locationBoards1 = np.array([17,28])
middle1 = np.median(locationBoards1)
locationBoards2 = np.array([32,36])
middle2 = np.median(locationBoards2)
print(middle1,middle2)




locationOfB = np.array([middle1,middle2])
# Location of B
print(middle1,middle2)


##Distance of B from Restaurant


distanceBFromRestaurant  = np.abs(locationOfB - Restaurant)
print(distanceBFromRestaurant)
print("Distance of First B Billboard is : " + str(distanceBFromRestaurant[0]))
print("Distance of Second B Billboard is : " + str(distanceBFromRestaurant[1]))
# Out:
# 22.5 34.0
# 22.5 34.0
# [7.5 4. ]
# Distance of First B Billboard is : 7.5
# Distance of Second B Billboard is : 4.0
